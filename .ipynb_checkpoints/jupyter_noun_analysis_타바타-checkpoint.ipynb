# %%
import sys
sys.path
# Out:
# ['/Users/noopy/instagram_hashtag_analysis',
#  '/Users/noopy/opt/anaconda3/lib/python37.zip',
#  '/Users/noopy/opt/anaconda3/lib/python3.7',
#  '/Users/noopy/opt/anaconda3/lib/python3.7/lib-dynload',
#  '',
#  '/Users/noopy/opt/anaconda3/lib/python3.7/site-packages',
#  '/Users/noopy/opt/anaconda3/lib/python3.7/site-packages/aeosa',
#  '/Users/noopy/opt/anaconda3/lib/python3.7/site-packages/IPython/extensions',
#  '/Users/noopy/.ipython']

# %%
exercise_name = "타바타"

# %%
file_name = "#" + exercise_name +"_sum.txt"
file_1 = "/Users/noopy/FitCuration/" + file_name
text = open(file_1, 'r',-1,"UTF-8",errors="ignore").read()
text
# Out:
# '#Repost @choihayeon0416 (@get_repost)\n・・・\n#공지 #무인gx #무인gx컨텐츠사업\n저희 #바디엔지니어스짐 에서 무인gx컨텐츠제작을시작합니다\n이건 샘플영상이고 여기서 음악 더빙작업과 자막작업 영상편집작업이더들어가게됩니다 촬영도 더 디테일하고 고화질로작업되구요\n올해부터 모든전지점 무인gx를점차적시행예정이구 기존유인gx는 기존대로 수업진행하며 나머지 am8시부터pm12시까지 full로gx가\n진행됩니다 단한명이라도 수업을들을수있는구조가 되는거죠 \n실제같은 무인gx수업되도록 노력하겠습니다\n#요가#줌바#다빈치보드#스트레칭#타바타 #댄스 여러가지 영상제작됩니다\n기대하셔도좋습니다\n#무인컨텐츠가필요하신센터는연락주세요\n#실력있는강사분도연락주세요 요가줌바댄스\n#미래에빨리다가가세요\n#컨텐츠계약\n#하루종일gx수업이있는센터\n\n#365일24시\n#무인헬스장\n#무인결제기\n#운동은원래여기서하는겁니다\n#프리미엄의진정한가치 \n#바디엔지니어스짐24\n#365일24시 #대구24시헬스 #무인헬스\n오늘도 감사합니다 🙏❤🥰\n2020년 부터\n#맨즈요가 #남자요가\n\'이리스요가\'에서 시작하세요 ~👫\n°\n°\n\u200b🌱🌿☘🍀🌳\n\u200b°\n함께 할수 있음에 감사드립니다 🙏 ♡베풂의 뿌리, 나무♡\n#이리스요가 IRISYOGA\n°\n°\n#부산 #정관요가 #정관필라테스 #정관다이어트 #다이어트전문 #체형교정전문 #근력운동 #정관신도시 #정관핫플 #정관개인레슨 #운동하는여자 #운동하는남자 #요가 #정관다이어트 #척추교정 #골반교정 #허리디스크 #타바타 #yoga #pilates #요가지도자과정\n#아마존 아닌\n우리엄마 #마미존\n-\n저희 형님께서 오픈하는 모두짐! 걍 말이 필요 없으니 이용해보세요^^ 제가 보증합니다~~수원,동탄 사는분들 얼른 레고레고💪💪\n-\n#리그램 - @simhyojoeng by @get_regrammer\n동탄2신도시 모두짐 오픈예정! \n프리미엄 G.X / PT 🖤\n-\n다이어트댄스/줌바댄스\n테라피요가/빈야사요가/힐링요가\n필라핏/타바타\n키즈방송댄스/키즈성장운동/키즈요가\n1:1PT / 그룹PT / 교정운동 / 테라피\n.\n.\n#모두짐\n#다이어트댄스 \n#줌바댄스\n#요가 \n#필라핏\n#타바타 \n#키즈방송댄스 \n#키즈성장운동\n#키즈요가 \n#1:1PT \n#그룹PT \n#다이어트 \
 괜찮다고 응원해주시는 회원님들\n항상 감사하고 사랑합니다~\n요즘 운동 다시 시작하신\n새로운 별명을 달고 오신 분\n아무도 안봐도 운동 열심히 하심\n깨알 선경쌤 출연시키기\n.\n다이어트\n신부준비\n출산준비\n체형교정\n근력증가\n멸치탈출\n선수준비\n체대입시\n디오션 피트니스에서 go~!!\n.\n#여수 #여천 #순천 #광양 #디오션피트니스 #디오션호텔 #디오션워터파크 #헬스 #요가 #에어로빅 #타바타 #스피닝 #줌바 #보디빌딩 #비키니 #피지크 #스포츠모델 #철학 #감성 #여수헬스 #선팔맞팔환영 #선팔맞팔 #ootd #헬스타그램 #운스타그램\nAT HOME TABATA WORKOUT 🔥\n\nSimple and easy way to exercise for your busy life. Step-by-step exercises for fat-burning: 1) volleyball block 2) skater 3) crab kicks 4) mountain climbers .\n.\nPerform 20 sec on and 10 sec off. 2 rounds total. \n#dailyworkout #bodyweightworkouts #HIIT #workoutforbusypeople #workoutathome\n.\n오늘도 어김없이 돌아온! 고민수와 함께하는 #하루운동 👊\n.\n.\n#타바타 #홈트레이닝 💪\n.\n1) 발리볼블락\n2) 스케이터\n3) 크랩킥\n4) 마운틴클라이머\n.\n20초 동작 수행. 10초 휴식. 총 2 라운드 (4분완성 👊)\n.\n. \n자세한 동작설명 운동영상은 유튜브 #고민수 채널 구독 ❤ .\n.\n#운동영상 #근력운동 #맨몸운동 #운동미션 #타바타운동\nLove of my life\n2019 해가든짐 진행 사안\n\n1. 해가든짐 상호명 개편!\n구 까르페디엠피트니스에서 읽기에 대한 난해함을 겪는 분들이 있고,  위치 및 입지 상황을 고려하여 상호명을 개명했습니다.\n\n2. 뉴텍 웰리스 8 스테이션 홈짐 구매  최고의 보디빌딩 선수 김준호 선수가 전속 모델로 뉴텍 웰리스를 홍보합니다. 동양인의 신체구조에 걸맞게 인체공학적으로 설계된 뉴텍 웰리스 그 중에서도\n8 스테이션은 여러명이 한 번에 운동을 해도 겹치지 않게 사용분리 되어진 최고의 토탈 홈짐 입니다.\n\n3.  가스 안전 공사 보일러 교체 완료\n* 보이지 않는 부분이지만 시설업은 소방법에 근거하여 엄중한 검토와 가스 안전사고에 노출을 보완해야합 ...

# %%
# -*- coding: utf-8 -*-
import re
def preprocessing_hangul(text):
    # 개행문자 제거
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')
    result = hangul.sub('', text)
    return result

clean_text = preprocessing_hangul(text)
clean_text
# Out:
# '  공지 무인 무인컨텐츠사업저희 바디엔지니어스짐 에서 무인컨텐츠제작을시작합니다이건 샘플영상이고 여기서 음악 더빙작업과 자막작업 영상편집작업이더들어가게됩니다 촬영도 더 디테일하고 고화질로작업되구요올해부터 모든전지점 무인를점차적시행예정이구 기존유인는 기존대로 수업진행하며 나머지 시부터시까지 로가진행됩니다 단한명이라도 수업을들을수있는구조가 되는거죠 실제같은 무인수업되도록 노력하겠습니다요가줌바다빈치보드스트레칭타바타 댄스 여러가지 영상제작됩니다기대하셔도좋습니다무인컨텐츠가필요하신센터는연락주세요실력있는강사분도연락주세요 요가줌바댄스미래에빨리다가가세요컨텐츠계약하루종일수업이있는센터일시무인헬스장무인결제기운동은원래여기서하는겁니다프리미엄의진정한가치
 피지크 스포츠모델 철학 감성 여수헬스 선팔맞팔환영 선팔맞팔  헬스타그램 운스타그램                                            오늘도 어김없이 돌아온 고민수와 함께하는 하루운동 타바타 홈트레이닝  발리볼블락 스케이터 크랩킥 마운틴클라이머초 동작 수행 초 휴식 총  라운드 분완성  자세한 동작설명 운동영상은 유튜브 고민수 채널 구독  운동영상 근력운동 맨몸운동 운동미션 타바타운동    해가든짐 진행 사안 해가든짐 상호명 개편구 까르페디엠피트니스에서 읽기에 대한 난해함을 겪는 분들이 있고  위치 및 입지 상황을 고려하여 상호명을 개명했습니다 뉴텍 웰리스  스테이션 홈짐 구매  최고의 보디빌딩 선수 김준호 선수가 전속 모델로 뉴텍 웰리스를 홍보합니다 동양인의 신체구조에 걸맞게 인체공학적으로 설계된 뉴텍 웰리스 그 중에서도 스테이션은 여러명이 한 번에 운동을 해도 겹치지 않게 사용분리 되어진 최고의 토탈 홈짐 입니다  가스 안전 공사 보일러 교체 완료 보이지 않는 부분이지만 시설업은 소방법에 근거하여 엄중한 검토와 가스 안전사고에 노출을 보완해야합니다  해가든 아파트 상가는 주변 상가 건물 중 가장 신축 건물로 쾌적함과 관리 그리고 넓은 주차공간을 확보하고 있는 흑석동 단연 최고의 건물입니다  이에 걸맞게 해가든짐은 안전 또한 이용고객에게 정말 중요한 요건이기 때문에  보다 안전한 최선의 시스템으로 일자에 가스안전 공사와 보일러 수리를 완료하였습니다  라커 키에서 넘버락으로 교체  공용 라커 시설은 헬스업계에서 가장 관리하기 힘든 부분입니다  키를 분실하시는 분 공용라커를 개인용도로 사용하시는 분 심지어 라커를 개 이상 사  용하시는 고객들도 있습니다  키를 한번 분실하게 되면 관리 차원에서는 키불출을 하기 위해 다시 수 많은 키를 구매해  서 배치해야 하는 번거로운 관리 입장이 있습니다  사용자가 임의 대로 번호를 설정하고 사용할 수 있는 공용라커  이제 사용 못 하시는 분은  없으시죠   년도 월 안으로 탈의실 바닥을 이용에 편의로울 수 있도록 완비하겠습니다시설을 보완하는 것들이 비록 눈에 보이지 않을지라도 회원님들께서 더욱이 편안하고 안전하게 운동할 수 있는 공간으로 최고일 수는 없지만 최선으로 노력하겠습니다 감사합니다 해가든짐 대표몇일만에 운동나왔는데관장님이 얼굴에 살쪄서 통통해졌다고ㅎㄷㄷ뒤늦게 보기좋게 라고 소근소근 하셨으나충격ㅎㄷㄷ 초반에 운동도 까먹어서 틀리고난리다 난리ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ당분간 열심히 다이어트해야지 다이어트 운동스타그램 셀피스타그램운동 후 너무도 극명히 다른 모습의 남과 여ㅋㅋㅋㅋㅍㅍ 프로젝트핏양재역 피트니스 양재헬스 양재크로스핏 양재휘트니스 몸만들기 타바타 건강스타그램 건강 다이어트 헬스타그램  피트니스타그램 몸스타그램 운동스타그램  웨이트 바디프로필 바디체크 다이어트 몸매관리 다이어트그램 운동파트너 양재시민의숲 홈트구의동 시설최고 프로그램 최고 복싱짐서울 복싱멘토스쿨 구의본점주소서울 광진구 구의동  금강테크노빌 층카톡채널복싱멘토스쿨서울 복싱멘토스쿨 청담점주소서울 강남구 청담동 카톡채널복싱멘토스쿨용인 복싱멘토스쿨 둔전점주소경기 용인시 처인구 포곡읍 둔전리  신성빌딩층카톡수원 복싱멘토스쿨 인계동점주소경기 수원시 팔달구 인계동 삼라빌딩 층 호카톡수원 복싱멘토스쿨 조원동점주소경기 수원시 장안구 금당로  그린프라자 호카톡시설 프로그램 좋아요 개인화보 단체수업  타바타 취미 방학 태양 넌나만바라봐 탑오늘의 점심소호동 하루횟집랍스터가 움직여동영상 있는데 귀찮연말이라고 계속 챙겨주시는감사한분들항상 겸손하고 친절한 자세로열심히 하겠습니다다이어트신부준비출산준비체형교정근력증가멸치탈출선수준비체대입시디오션 피트니스에서 여수 여천 순천 광양 디오션피트니스 디오션호텔 디오션워터파크 헬스 요가 에어로빅 타바타 스피닝 줌바 보디빌딩 비키니 피지크 스포츠모델 철학 감성 여수헬스 선팔맞팔환영 선팔맞팔  헬스타그램 운스타그램사회복지시설박애원 내일 만나러 갑니다 이리스요가 회원님들께 넘넘 감사드립니다 따뜻한 마음 꼭 전달하고 오겠습니다 사랑을 나눠주셔서 감사합니다 따뜻한 마음을 전달할수있는 좋은 자리를 만들어주셔서 감사합니다 함께 할수 있음에 감사드립니다  베풂의 뿌리 나무이리스요가 부산 정관요가 정관필라테스 정관다이어트 다이어트전문 체형교정전문 근력운동 정관신도시 정관핫플 정관개인레슨 운동하는여자 운동하는남자 요가 정관다이어트 척추교정 골반교정 허리디스크 타바타   요가지도자과정동탄신도시 모 ...

# %%
from konlpy.tag import Mecab
mecab = Mecab()
noun_list_mecab = mecab.nouns(clean_text)

# stopwards preprocessing
stopwords_mecab = ['수','퀄리티','도시','분','전문','스타','년','원'] 

clean_noun_list_mecab = []

for n in noun_list_mecab:
    if n not in stopwords_mecab:
        clean_noun_list_mecab.append(n)

# get top 100 most common nouns
from collections import Counter
nouns_mecab = Counter(clean_noun_list_mecab)

tags_mecab = nouns_mecab.most_common(100)
tags_mecab
# Out:
# [('운동', 2558),
#  ('다이어트', 1438),
#  ('타바타', 1210),
#  ('복싱', 835),
#  ('댄스', 683),
#  ('그램', 603),
#  ('헬스', 599),
#  ('요가', 594),
#  ('핏', 528),
#  ('구미', 486),
#  ('짐', 462),
#  ('키즈', 457),
#  ('건강', 446),
#  ('그룹', 411),
#  ('피닝', 356),
#  ('바디', 348),
#  ('교정', 322),
#  ('바', 292),
#  ('테라', 282),
#  ('수업', 260),
#  ('줌', 257),
#  ('필라테스', 250),
#  ('광주', 246),
#  ('양재', 244),
#  ('동탄', 233),
#  ('맛집', 231),
#  ('니스', 228),
#  ('트레이닝', 227),
#  ('홈', 223),
#  ('크로스', 218),
#  ('경기', 216),
#  ('피', 207),
#  ('팔', 205),
#  ('키', 200),
#  ('방송', 194),
#  ('피트', 194),
#  ('즈', 192),
#  ('필라', 188),
#  ('장운동', 187),
#  ('여자', 181),
#  ('유산소', 169),
#  ('체력', 168),
#  ('트', 158),
#  ('오픈', 153),
#  ('센터', 151),
#  ('서킷', 150),
#  ('진해', 148),
#  ('오늘', 147),
#  ('근력', 147),
#  ('문', 147),
#  ('킥복싱', 133),
#  ('중', 132),
#  ('체형', 122),
#  ('시간', 122),
#  ('몸', 118),
#  ('장', 118),
#  ('힐링', 117),
#  ('체육관', 116),
#  ('프리미엄', 115),
#  ('웨이트', 115),
#  ('시', 112),
#  ('남자', 111),
#  ('관리', 111),
#  ('회원', 111),
#  ('개인', 108),
#  ('번', 108),
#  ('것', 107),
#  ('증진', 106),
#  ('선수', 106),
#  ('점', 105),
#  ('점핑', 105),
#  ('영상', 104),
#  ('무인', 103),
#  ('스텝', 101),
#  ('김', 100),
#  ('나', 99),
#  ('시작', 98),
#  ('예정', 98),
#  ('체육', 97),
#  ('정의', 97),
#  ('회관', 97),
#  ('거', 96),
#  ('레슨', 96),
#  ('무산소', 96),
#  ('준비', 96),
#  ('사요', 95),
#  ('가빈', 93),
#  ('파트너', 93),
#  ('일', 92),
#  ('스트레칭', 91),
#  ('체크', 89),
#  ('옥계', 89),
#  ('싱', 89),
#  ('닝', 89),
#  ('휘트', 88),
#  ('박스', 87),
#  ('구', 87),
#  ('맘', 87),
#  ('주말', 87),
#  ('카톡', 85)]

# %%
#Twitter, which has changed to Okt
from konlpy.tag import Okt
okt = Okt()
noun_list_okt = okt.nouns(clean_text)

stopwords_okt = ['수','퀄리티','도시','분','전문','스타','년','원'] 

clean_noun_list_okt = []

for n in noun_list_okt:
  if n not in stopwords_okt:
    clean_noun_list_okt.append(n)


from collections import Counter
nouns_okt = Counter(clean_noun_list_okt)
# counted_nouns

tags_okt = nouns_okt.most_common(100)
tags_okt
# Out:
# [('운동', 2660),
#  ('다이어트', 1441),
#  ('바타', 916),
#  ('복싱', 832),
#  ('요가', 659),
#  ('댄스', 652),
#  ('키즈', 644),
#  ('그램', 597),
#  ('구미', 462),
#  ('짐', 434),
#  ('타바', 427),
#  ('그룹', 411),
#  ('바디', 363),
#  ('건강', 345),
#  ('교정', 324),
#  ('헬스', 305),
#  ('피', 301),
#  ('핏', 296),
#  ('줌바', 285),
#  ('테라', 283),
#  ('수업', 257),
#  ('맛집', 251),
#  ('필라테스', 250),
#  ('광주', 246),
#  ('트레이닝', 235),
#  ('크로스핏', 215),
#  ('경기', 212),
#  ('방송', 191),
#  ('피트니스', 191),
#  ('성장', 189),
#  ('동탄신도시', 186),
#  ('양재', 184),
#  ('오늘', 183),
#  ('여자', 182),
#  ('몸', 179),
#  ('스피닝', 168),
#  ('문의', 163),
#  ('오픈', 154),
#  ('센터', 151),
#  ('서킷', 151),
#  ('모두', 149),
#  ('진해', 148),
#  ('근력', 146),
#  ('층', 142),
#  ('체력', 141),
#  ('타', 138),
#  ('헬스장', 137),
#  ('산소', 137),
#  ('킥복싱', 134),
#  ('헬', 132),
#  ('트', 127),
#  ('체육관', 125),
#  ('체형', 122),
#  ('힐링', 117),
#  ('스', 117),
#  ('프리미엄', 115),
#  ('시간', 112),
#  ('더', 111),
#  ('동탄', 111),
#  ('스텝', 110),
#  ('웨이', 109),
#  ('회원', 109),
#  ('휘트니', 108),
#  ('관리', 107),
#  ('유', 107),
#  ('증진', 106),
#  ('점핑', 106),
#  ('체육', 104),
#  ('맞팔', 104),
#  ('무인', 103),
#  ('남자', 103),
#  ('홈트', 103),
#  ('무', 102),
#  ('회관', 99),
#  ('예정', 98),
#  ('정의', 98),
#  ('레슨', 96),
#  ('점', 96),
#  ('필라', 95),
#  ('개인', 93),
#  ('가빈', 93),
#  ('야사', 93),
#  ('가필', 93),
#  ('파트너', 93),
#  ('스트레칭', 92),
#  ('영상', 91),
#  ('준비', 91),
#  ('체크', 90),
#  ('옥계', 90),
#  ('시작', 89),
#  ('주말', 86),
#  ('카톡', 85),
#  ('울산', 85),
#  ('박스', 83),
#  ('프로젝트', 82),
#  ('선팔', 81),
#  ('월', 80),
#  ('상담', 80),
#  ('몸매', 79),
#  ('펌프', 79)]

# %%
# Komoran
# takes too much time.
"""
from konlpy.tag import Komoran
komoran = Komoran()
noun_list_komoran = komoran.nouns(clean_text)

stopwords_komoran = ['수','퀄리티','도시','분','전문','스타','년','원'] 

clean_noun_list_komoran = []

for n in noun_list_komoran:
  if n not in stopwords_komoran:
    clean_noun_list_komoran.append(n)


from collections import Counter
nouns_komoran = Counter(clean_noun_list_komoran)
# counted_nouns

tags_komoran = nouns_komoran.most_common(100)
tags_komoran
"""
# Out:
# [('운동', 2219),
#  ('다이어트', 1180),
#  ('복싱', 749),
#  ('바타', 721),
#  ('그램', 551),
#  ('바', 455),
#  ('헬스', 435),
#  ('짐', 425),
#  ('건강', 414),
#  ('요가', 406),
#  ('댄스', 375),
#  ('그룹', 372),
#  ('키즈', 359),
#  ('구미', 313),
#  ('디', 311),
#  ('모두', 264),
#  ('타바', 263),
#  ('피', 246),
#  ('광주', 231),
#  ('교정', 229),
#  ('수업', 219),
#  ('맛집', 219),
#  ('몸', 217),
#  ('경기', 216),
#  ('테라', 200),
#  ('트레이닝', 197),
#  ('크로스핏', 195),
#  ('피트니스', 185),
#  ('양재', 183),
#  ('필라테스', 179),
#  ('문', 175),
#  ('동탄신도시', 171),
#  ('줌', 167),
#  ('점', 161),
#  ('체력', 160),
#  ('오늘', 157),
#  ('오픈', 152),
#  ('시', 148),
#  ('서킷', 146),
#  ('홈', 145),
#  ('진해', 137),
#  ('근력', 136),
#  ('층', 131),
#  ('장', 128),
#  ('여자', 127),
#  ('유산', 127),
#  ('킥복싱', 126),
#  ('중', 123),
#  ('산소', 119),
#  ('소', 116),
#  ('시간', 114),
#  ('체육관', 113),
#  ('남', 113),
#  ('것', 113),
#  ('동탄', 111),
#  ('번', 109),
#  ('웨이트', 105),
#  ('센터', 105),
#  ('요', 104),
#  ('증진', 102),
#  ('관리', 102),
#  ('방송', 100),
#  ('회원', 100),
#  ('예정', 98),
#  ('개인', 98),
#  ('선수', 98),
#  ('프리미엄', 96),
#  ('성장', 96),
#  ('남자', 94),
#  ('회관', 93),
#  ('정의', 92),
#  ('팔', 92),
#  ('체육', 89),
#  ('준비', 88),
#  ('거', 87),
#  ('영상', 85),
#  ('스트레칭', 85),
#  ('파트너', 85),
#  ('스텝', 85),
#  ('체크', 81),
#  ('일', 81),
#  ('박스', 79),
#  ('상담', 78),
#  ('시작', 77),
#  ('몸매', 77),
#  ('진행', 76),
#  ('월', 76),
#  ('레스', 75),
#  ('경북', 72),
#  ('초', 71),
#  ('일상', 71),
#  ('유아', 70),
#  ('창원', 70),
#  ('이', 70),
#  ('프로필', 69),
#  ('팀', 69),
#  ('싱', 69),
#  ('감사', 68),
#  ('록', 68),
#  ('점핑', 68)]

# %%
# # Kkma
# from konlpy.tag import Kkma
# kkoma = Kkma()
# noun_list_kkoma = kkoma.nouns(clean_text)

# stopwords_kkoma = ['수','퀄리티','도시','분','전문','스타','년','원'] 

# clean_noun_list_kkoma = []

# for n in clean_noun_list_kkoma:
#   if n not in stopwords_kkoma:
#     clean_noun_list_kkoma.append(n)


# from collections import Counter
# nouns_kkoma = Counter(clean_noun_list_kkoma)
# # counted_nouns

# tags_kkoma = nouns_kkoma.most_common(100)
# tags_kkoma
# Out:
# []

# %%
# get emojis used in instagram accounts 
import emoji

def extract_emojis(str):
  emoji_string = ''.join(c for c in str if c in emoji.UNICODE_EMOJI)
  return emoji_string

emoji_string = extract_emojis(text)

from collections import Counter
common_emoji = Counter(emoji_string)
top_100_emojis = common_emoji.most_common(100)
top_100_emojis
# Out:
# [('🏻', 229),
#  ('👉', 216),
#  ('🥊', 197),
#  ('✅', 168),
#  ('☎', 157),
#  ('👍', 154),
#  ('🖤', 139),
#  ('🏼', 131),
#  ('🔥', 114),
#  ('♀', 110),
#  ('❤', 101),
#  ('👏', 96),
#  ('💪', 88),
#  ('✔', 81),
#  ('▫', 80),
#  ('👊', 64),
#  ('✨', 60),
#  ('💕', 52),
#  ('😁', 49),
#  ('🙏', 48),
#  ('🤗', 47),
#  ('📱', 44),
#  ('💐', 43),
#  ('📍', 42),
#  ('♂', 38),
#  ('🏽', 38),
#  ('🏃', 36),
#  ('🏋', 36),
#  ('📞', 36),
#  ('😭', 32),
#  ('➖', 32),
#  ('🤣', 31),
#  ('◾', 30),
#  ('🏆', 29),
#  ('🥰', 28),
#  ('💃', 28),
#  ('😆', 27),
#  ('⭐', 27),
#  ('💛', 25),
#  ('🤩', 23),
#  ('🌟', 23),
#  ('❗', 22),
#  ('😍', 22),
#  ('🥇', 21),
#  ('🆗', 20),
#  ('😱', 20),
#  ('😊', 19),
#  ('✌', 18),
#  ('♥', 18),
#  ('💌', 18),
#  ('🤦', 18),
#  ('😂', 17),
#  ('▪', 17),
#  ('🤔', 16),
#  ('😅', 16),
#  ('🙆', 15),
#  ('🎉', 14),
#  ('▶', 14),
#  ('💜', 14),
#  ('⭕', 14),
#  ('‼', 14),
#  ('😢', 13),
#  ('➡', 13),
#  ('🤭', 13),
#  ('💥', 13),
#  ('🥳', 12),
#  ('☺', 12),
#  ('😘', 11),
#  ('💎', 11),
#  ('🙋', 11),
#  ('💙', 11),
#  ('🙄', 11),
#  ('📲', 10),
#  ('💦', 10),
#  ('⬆', 10),
#  ('👩', 10),
#  ('😎', 10),
#  ('✊', 10),
#  ('☝', 10),
#  ('♨', 10),
#  ('🤤', 9),
#  ('🙇', 9),
#  ('😝', 9),
#  ('🤪', 9),
#  ('🚴', 8),
#  ('🙌', 8),
#  ('👀', 8),
#  ('💗', 8),
#  ('🥺', 7),
#  ('⚽', 7),
#  ('🙈', 7),
#  ('🤸', 7),
#  ('🧡', 7),
#  ('🤜', 7),
#  ('😃', 7),
#  ('🌈', 7),
#  ('🌱', 6),
#  ('🌿', 6),
#  ('☘', 6),
#  ('🍀', 6)]
