# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(analyzer = 'word', # 캐릭터 단위로 벡터화 할 수도 있습니다.
                             tokenizer = None, # 토크나이저를 따로 지정해 줄 수도 있습니다.
                             preprocessor = None, # 전처리 도구
                             stop_words = None, # 불용어 nltk등의 도구를 사용할 수도 있습니다.
                             min_df = 2, # 토큰이 나타날 최소 문서 개수로 오타나 자주 나오지 않는 특수한 전문용어 제거에 좋습니다. 
                             ngram_range=(3, 6), # BOW의 단위 갯수의 범위를 지정합니다.
                             max_features = 2000 # 만들 피처의 수, 단어의 수
                            )
vectorizer
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=2000, min_df=2,
#                 ngram_range=(3, 6), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt

# %matplotlib inline
# 시각화 결과가 선명하게 표시되도록
# %config InlineBackend.figure_format = 'retina'

df = pd.read_csv("combined_wrangling_db.csv")
df.shape
# Out:
# (100, 248)

# %%
df
# Out:
#     PT 등장횟수  관련명사  PT 등장횟수.1 관련서술어  PT 등장횟수.2 관련명사.1  PT 등장횟수.3 관련서술어.1  \
# 0       263    운동         13    많은        263     운동         13      많은
# 1       164    헬스         13   좋아요        164     헬스         13     좋아요
# 2       102  다이어트         12     들        102   다이어트         12       들
# 3        83  필라테스          9    해서         83   필라테스          9      해서
# 4        64    니스          9    좋은         64     니스          9      좋은
# ..      ...   ...        ...   ...        ...    ...        ...     ...
# 95       10   퍼스널          2    쏘마         10    퍼스널          2      쏘마
# 96       10   코로나          2  힘들어도         10    코로나          2    힘들어도
# 97       10    교정          2    하자         10     교정          2      하자
# 98       10   휘트니          2   그러니         10    휘트니          2     그러니
# 99       10     손          2   였어요         10      손          2     였어요
#
#     검도 등장횟수 관련명사.2  ...  핫요가 등장횟수.1 관련서술어.59  헬스 등장횟수 관련명사.60  헬스 등장횟수.1  \
# 0      2051     검도  ...         238      좋아요     1306      운동        110
# 1       596     운동  ...         202       아쉬      953      헬스        107
# 2       522      검  ...          73      다양한      336    다이어트         54
# 3       451     도관  ...          69      소소한      270       팔         53
# 4       232     동검  ...          58        들      263    필라테스         47
# ..      ...    ...  ...         ...      ...      ...     ...        ...
# 95       38      거  ...           9       비움       39      환영          6
# 96       37      관  ...           9       좋다       39    보디빌딩          6
# 97       37     수영  ...           9       힘든       39      직장          6
# 98       37     부산  ...           9    하겠습니다       39      참여          6
# 99       37     인천  ...           9       싶은       39       바          6
#
#    관련서술어.60  힙레 등장횟수 관련명사.61  힙레 등장횟수.1 관련서술어.61
# 0       좋아요      747       힙         76      열리는
# 1         챌      710      발레         46      자세한
# 2        좋은      478      운동         42       이어
# 3         좋      464    포레스티         40       바꿀
# 4        하면      452       벌         38       되는
# ..      ...      ...     ...        ...      ...
# 95        본       40      추천          5      완벽한
# 96  만들어졌습니다       40      먼스          5      되었던
# 97    부탁드려요       40       잇          5      만들고
# 98      되는신       39      영리          5      보이는
# 99       짜잔       39     캠페인          5        본
#
# [100 rows x 248 columns]
